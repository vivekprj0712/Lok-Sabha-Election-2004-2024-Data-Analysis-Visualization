# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekprj0712/Lok-Sabha-Election-2004-2024-Data-Analysis-Visualization/blob/master/Prob%26Stats_Lok_Sabha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown https://drive.google.com/uc?id=1KGotZwFADFXIY0ZbKBN2KHh_2zcTU43w
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1KGotZwFADFXIY0ZbKBN2KHh_2zcTU43w
# To: /content/FinalElectionData(2004-2024).csv
# 100% 288k/288k [00:00<00:00, 44.5MB/s]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('FinalElectionData(2004-2024).csv')

# %%
df
# Out:
#               PC Name Caste        State             Winning Candidate  \
# 0          Ahmadnagar   GEN  Maharashtra  Gandhi Dilipkumar Mansukhlal
# 1      Ahmedabad East   GEN      Gujarat                  Harin Pathak
# 2               Akola   GEN  Maharashtra         Dhotre Sanjay Shamrao
# 3              Amreli   GEN      Gujarat           Kachhadia Naranbhai
# 4            Amritsar   GEN       Punjab            Navjot Singh Sidhu
# ...               ...   ...          ...                           ...
# 2708         Uluberia   GEN  West Bengal                  Sultan Ahmed
# 2709         Vaishali   GEN        Bihar       Raghuvansh Prasad Singh
# 2710    Valmiki Nagar   GEN        Bihar       Baidyanath Prasad Mahto
# 2711          Vellore   GEN   Tamil Nadu                  Abdul Rahman
# 2712  Yavatmal-Washim   GEN  Maharashtra        Bhavana Gawali (Patil)
#
#                              Party  Electors    Votes  Turnout  Margin  \
# ...

# %%
df.head()
# Out:
#           PC Name Caste        State             Winning Candidate  \
# 0      Ahmadnagar   GEN  Maharashtra  Gandhi Dilipkumar Mansukhlal
# 1  Ahmedabad East   GEN      Gujarat                  Harin Pathak
# 2           Akola   GEN  Maharashtra         Dhotre Sanjay Shamrao
# 3          Amreli   GEN      Gujarat           Kachhadia Naranbhai
# 4        Amritsar   GEN       Punjab            Navjot Singh Sidhu
#
#                    Party  Electors   Votes  Turnout  Margin  Margin %  Year
# 0  Bharatiya Janta Party   1517951  787153    0.519   46731     0.059  2009
# 1  Bharatiya Janta Party   1411761  597395    0.423   86056     0.144  2009
# 2  Bharatiya Janta Party   1480606  740014    0.500   64848     0.088  2009
# 3  Bharatiya Janta Party   1312733  524642    0.400   37317     0.071  2009
# 4  Bharatiya Janta Party   1241099  814503    0.656    6858     0.008  2009

# %%
df.tail()
# Out:
#               PC Name Caste        State        Winning Candidate  \
# 2708         Uluberia   GEN  West Bengal             Sultan Ahmed
# 2709         Vaishali   GEN        Bihar  Raghuvansh Prasad Singh
# 2710    Valmiki Nagar   GEN        Bihar  Baidyanath Prasad Mahto
# 2711          Vellore   GEN   Tamil Nadu             Abdul Rahman
# 2712  Yavatmal-Washim   GEN  Maharashtra   Bhavana Gawali (Patil)
#
#                              Party  Electors    Votes  Turnout  Margin  \
# 2708  All India Trinamool Congress   1251590  1009905    0.807   98936
# 2709          Rashtriya Janata Dal   1278891   624863    0.489   22308
# 2710           Janata Dal (United)   1275653   598456    0.469  183675
# 2711      Dravida Munetra Kazhagam   1010067   723658    0.716  107393
# 2712                     Shiv Sena   1554042   840574    0.541   56951
#
#       Margin %  Year
# 2708     0.098  2009
# 2709     0.036  2009
# 2710     0.307  2009
# 2711     0.148  2009
# 2712     0.068  2009

# %%
df.describe()
# Out:
#            Electors         Votes      Turnout        Margin     Margin %  \
# count  2.713000e+03  2.713000e+03  2713.000000  2.713000e+03  2713.000000
# mean   1.504152e+06  9.648643e+05     0.647782  1.357541e+05     0.136487
# std    3.685074e+05  2.812008e+05     0.126124  1.271395e+05     0.111378
# min    3.903300e+04  0.000000e+00     0.097000  3.600000e+01     0.000000
# 25%    1.285794e+06  7.650590e+05     0.557000  4.240400e+04     0.051000
# 50%    1.500160e+06  9.856370e+05     0.649000  9.998900e+04     0.110000
# 75%    1.738001e+06  1.151170e+06     0.745000  1.916120e+05     0.197000
# max    3.779596e+06  2.453608e+06     1.081000  1.606425e+06     1.000000
#
#               Year
# count  2713.000000
# mean   2013.996314
# std       7.073674
# min    2004.000000
# 25%    2009.000000
# 50%    2014.000000
# 75%    2019.000000
# max    2024.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2713 entries, 0 to 2712
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PC Name            2713 non-null   object
#  1   Caste              2713 non-null   object
#  2   State              2713 non-null   object
#  3   Winning Candidate  2713 non-null   object
#  4   Party              2713 non-null   object
#  5   Electors           2713 non-null   int64
#  6   Votes              2713 non-null   int64
#  7   Turnout            2713 non-null   float64
#  8   Margin             2713 non-null   int64
#  9   Margin %           2713 non-null   float64
#  10  Year               2713 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 233.3+ KB

# %%
df.isnull().sum()
# Out:
# PC Name              0
# Caste                0
# State                0
# Winning Candidate    0
# Party                0
# Electors             0
# Votes                0
# Turnout              0
# Margin               0
# Margin %             0
# Year                 0
# dtype: int64

# %% [markdown]
# # Central Tendency: Calculate mean and median for voter turnout, votes, and margins.

# %%
df.describe()
# Out:
#            Electors         Votes      Turnout        Margin     Margin %  \
# count  2.713000e+03  2.713000e+03  2713.000000  2.713000e+03  2713.000000
# mean   1.504152e+06  9.648643e+05     0.647782  1.357541e+05     0.136487
# std    3.685074e+05  2.812008e+05     0.126124  1.271395e+05     0.111378
# min    3.903300e+04  0.000000e+00     0.097000  3.600000e+01     0.000000
# 25%    1.285794e+06  7.650590e+05     0.557000  4.240400e+04     0.051000
# 50%    1.500160e+06  9.856370e+05     0.649000  9.998900e+04     0.110000
# 75%    1.738001e+06  1.151170e+06     0.745000  1.916120e+05     0.197000
# max    3.779596e+06  2.453608e+06     1.081000  1.606425e+06     1.000000
#
#               Year
# count  2713.000000
# mean   2013.996314
# std       7.073674
# min    2004.000000
# 25%    2009.000000
# 50%    2014.000000
# 75%    2019.000000
# max    2024.000000

# %%
mean_turnout = df['Turnout'].mean()
print(mean_turnout)

mean_votes = df['Votes'].mean()
print(mean_votes)

mean_margin = df['Margin'].mean()
mean_margin
# Out:
# 0.6477817913748618
# 964864.2539624033
# 135754.14080353852

# %%
median_turnout = df['Turnout'].median()
print(median_turnout)

median_votes = df['Votes'].median()
print(median_votes)

median_margin = df['Margin'].median()
print(median_margin)
# Out:
# 0.649
# 985637.0
# 99989.0

# %%
# Dispersion: Calculate standard deviation, variance, range, and interquartile range for turnout and margins.
# Turnout

mean_turnout = df['Turnout'].mean()
print(mean_turnout)
diff = df['Turnout']-mean_turnout
diff
square_diff = diff ** 2
square_diff

variance = square_diff.mean()
print(variance)

# var_data = df['Turnout'].var(ddof=0)
# var_data
# Out:
# 0.6477817913748618
# 0.015901379587354925

# %%
# Margin

mean_margin = df['Margin'].mean()
print(mean_margin)
diff1 = df['Margin'] - mean_margin
diff1
square_diff1 = diff1 ** 2
square_diff1

variance1 = square_diff1.mean()
print(variance1)

# var_data1 = df['Margin'].var(ddof=0)
# var_data1
# Out:
# 135754.14080353852
# 16158496517.091862

# %% [markdown]
# Standard deviation

# %%
# Turnout
std_deviation = variance ** (1/2)
print(std_deviation)

# Margin
std_deviation1 = variance1 ** (1/2)
print(std_deviation1)

# std_mar = df['Margin'].std(ddof=0)
# print(std_mar)
# Out:
# 0.12610067243022507
# 127116.07497516536

# %% [markdown]
# Range

# %%
# Turnout
range_turnout = df['Turnout'].max() - df['Turnout'].min()
print(range_turnout)

# Margin
range_margin = df['Margin'].max() - df['Margin'].min()
print(range_margin)
# Out:
# 0.984
# 1606389

# %% [markdown]
# Voter Turnout
# Statistics: Average voter turnout, standard deviation, and comparison with previous elections.
#
# Distribution: Frequency distribution of voter turnout across different states or constituencies

# %%
# Group the data by year and calculate the average and standard deviation of turnout
turnout_stats = df.groupby('Year')['Turnout'].agg(['mean', 'std']).reset_index()
turnout_stats.columns = ['Year', 'Average Turnout', 'Standard Deviation']

turnout_stats
# Out:
#    Year  Average Turnout  Standard Deviation
# 0  2004         0.589818            0.118537
# 1  2009         0.594129            0.140019
# 2  2014         0.672720            0.102923
# 3  2019         0.712974            0.116861
# 4  2024         0.669508            0.100754

# %%
plt.figure(figsize=(10, 6))
plt.plot(turnout_stats['Year'], turnout_stats['Average Turnout'], marker='o', linestyle='-', color='black')
plt.fill_between(turnout_stats['Year'] , turnout_stats['Average Turnout'] - turnout_stats['Standard Deviation'] , turnout_stats['Average Turnout'] + turnout_stats['Standard Deviation'] , color='black', alpha=0.4)
plt.title('Average Voter Turnout Over the Years')
plt.xlabel('Year')
plt.ylabel('Average Turnout')
plt.xticks(turnout_stats['Year'])
plt.grid(True)
plt.show()

# %%
state_turnout = df.groupby('State')['Turnout'].mean().reset_index()

plt.figure(figsize=(12, 7))
plt.hist(state_turnout['Turnout'], bins=20, color  = 'teal',  edgecolor='k', alpha=1)
plt.title('Frequency Distribution of Voter Turnout Across States')
plt.xlabel('Average Turnout')
plt.ylabel('Frequency')
plt.grid(True)
#plt.xticks(turnout_stats['Average Turnout'])
plt.show()

# %%
pc_name_Turnout = df.groupby('PC Name')['Turnout'].mean().reset_index()

plt.figure(figsize=(12, 7))
plt.hist(pc_name_Turnout['Turnout'], bins=20, color = 'teal',  edgecolor='k', alpha=1)
plt.title('Frequency Distribution of Voter Turnout Across Constituencies')
plt.xlabel('Turnout')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
#  Election Results
# Statistics: Mean, median, and mode of votes received by candidates/parties.
#
# Distribution: Distribution of seats won by each party across the country.

# %%
import scipy.stats as stats

# %%
votes_stats = df.groupby('Party')['Votes'].agg(['mean', 'median' ,  lambda a: stats.mode(a)[0] ]).reset_index()
votes_stats.columns = ['Year', 'Mean', 'Median' , 'Mode' ]
votes_stats
# Out:
#                                         Year          Mean     Median     Mode
# 0                            Aam Aadmi Party  1.053078e+06  1054615.0   948485
# 1             Aazad Samaj Party (Kanshi Ram)  1.001303e+06  1001303.0  1001303
# 2                                 Ajsu Party  1.264833e+06  1264833.0  1264833
# 3   All India Anna Dravida Munnetra Kazhagam  9.964655e+05  1012667.0   719031
# 4                     All India Forward Bloc  9.635906e+05   947381.0   694449
# ..                                       ...           ...        ...      ...
# 73              United Peoples Party Liberal  1.241496e+06  1241496.0  1241496
# 74            Viduthalai Chiruthaigal Katchi  1.085590e+06  1152929.5   869428
# 75                 Voice Of The People Party  1.037911e+06  1037911.0  1037911
# 76     Yuvajana Sramika Rythu Congress Party  1.238679e+06  1234655.0   909614
# 77                   Zoram People’s Movement  4.913360e+05   491336.0   491336
#
# [78 rows x 4 columns]

# %%
# Calculate mean, median, and mode for the 'Votes' column
mean_votes = df['Votes'].mean()
median_votes = df['Votes'].median()
mode_votes = df['Votes'].mode()[0]

mean_votes, median_votes, mode_votes
# Out:
# (964864.2539624033, 985637.0, 598332)

# %%
# Plot the distribution of votes
plt.figure(figsize=(15, 6))
sns.histplot(df['Votes'], bins=30,color='teal')

# Plot mean, median, and mode
plt.axvline(mean_votes, color='black', linestyle='--', linewidth=2, label=f'Mean: {mean_votes:.0f}')
plt.axvline(median_votes, color='gold', linestyle='-', linewidth=2, label=f'Median: {median_votes:.0f}')
plt.axvline(mode_votes, color='slateblue', linestyle='-.', linewidth=2, label=f'Mode: {mode_votes:.0f}')

# Add labels and title
plt.xlabel('Votes')
plt.ylabel('Frequency')
plt.title('Distribution of Votes Received by Candidates/Parties')
plt.legend()

plt.show()

# %%
seats_won = df['Party'].value_counts()
print(seats_won)
# Out:
# Party
# Bharatiya Janta Party                       1078
# Indian National Congress                     546
# Samajwadi Party                              106
# All India Trinamool Congress                 106
# Communist Party Of India (Marxist)            75
#                                             ...
# Hindustani Awam Morcha (Secular)               1
# Nationalist Democratic Progressive Party       1
# United Peoples Party Liberal                   1
# Zoram People’s Movement                        1
# Jharkhand Vikas Morcha (Prajatantrik)          1
# Name: count, Length: 78, dtype: int64

# %%
plt.figure(figsize=(27, 15))
plt.bar(seats_won.index , seats_won.values ,  color = 'teal' , alpha = 1)
plt.title('Number of Seats Won by Each Party')
plt.xlabel('Party')
plt.ylabel('Number of Seats Won')
plt.grid(True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Distribution: Plot histograms and box plots to understand the distribution of votes, turnout, and margins.

# %%
# histograms
plt.figure(figsize=(15, 10))

plt.subplot(2, 3, 1)
plt.hist(df['Votes'], bins=10, edgecolor='k')
plt.title('Votes Histogram')
plt.xlabel('Votes')
plt.ylabel('range')

plt.subplot(2, 3, 2)
plt.hist(df['Turnout'], bins=10, edgecolor='k')
plt.title('Turnout Histogram')
plt.xlabel('Turnout')
plt.ylabel('range')

plt.subplot(2, 3, 3)
plt.hist(df['Margin'], bins=10, edgecolor='k')
plt.title('Margins Histogram')
plt.xlabel('Margins')
plt.ylabel('range')
# Out:
# Text(0, 0.5, 'range')

# %% [markdown]
# Box Plot

# %%
df[['Turnout','Margin']]
# Out:
#       Turnout  Margin
# 0       0.519   46731
# 1       0.423   86056
# 2       0.500   64848
# 3       0.400   37317
# 4       0.656    6858
# ...       ...     ...
# 2708    0.807   98936
# 2709    0.489   22308
# 2710    0.469  183675
# 2711    0.716  107393
# 2712    0.541   56951
#
# [2713 rows x 2 columns]

# %%
# box plots
plt.figure(figsize=(15,10))

plt.subplot(2, 3, 4)
sns.boxplot(y=df['Votes'])
plt.title('Votes Box Plot')
plt.xlabel('Votes')

plt.subplot(2, 3, 5)
sns.boxplot(y=df['Turnout'])
plt.title('Turnout Box Plot')
plt.xlabel('Turnout')

plt.subplot(2, 3, 6)
sns.boxplot(y=df['Margin'])
plt.title('Margins Box Plot')
plt.xlabel('Margins')
# Out:
# Text(0.5, 0, 'Margins')

# %% [markdown]
# Demographic Analysis:
# Probability: Likelihood of voting patterns based on caste.
#
# Statistics: Descriptive statistics like mean caster of voters, caste ratio, etc.
#
# Distribution: Demographic distribution of voters and their preferences.

# %%
mean_voting_rate = df.groupby('Caste')['Votes'].mean()
print("Mean Voting Rate by Caste:")
print(mean_voting_rate)
# Out:
# Mean Voting Rate by Caste:
# Caste
# GEN            9.598697e+05
# GENP           3.438345e+05
# SC             9.837858e+05
# ST             9.348338e+05
# Unspecified    1.164981e+06
# Name: Votes, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Caste', data=df)
plt.xlabel('Caste')
plt.ylabel('Count')
plt.title('Distribution of Voters by Caste')
plt.show()

# %%
# Calculate average turnout by caste
turnout_by_caste = df.groupby('Caste')['Turnout'].mean()
print("Average Turnout by Caste:")
print(turnout_by_caste)

# Calculate total votes by state
votes_by_state = df.groupby('State')['Votes'].sum()
print("\nTotal Votes by State:")
print(votes_by_state)
# Out:
# Average Turnout by Caste:
# Caste
# GEN            0.639073
# GENP           0.828000
# SC             0.641981
# ST             0.689866
# Unspecified    0.810345
# Name: Turnout, dtype: float64
#
# Total Votes by State:
# State
# Andaman & Nicobar Islands       924049
# Andhra Pradesh               172126723
# Arunachal Pradesh              2856212
# Assam                         74590950
# Bihar                        173710652
# Chandigarh                     1972695
# Chhattisgarh                  56627917
# Dadra & Nagar Haveli            764919
# Daman & Diu                     390725
# Delhi                         35769225
# Goa                            3692462
# Gujarat                      116704731
# Haryana                       53479682
# Himachal Pradesh              16193072
# Jammu & Kashmir               17111850
# Jharkhand                     63686875
# Karnataka                    154631201
# Kerala                        89461927
# ...

# %%
# Distribution: Demographic distribution of voters and their preferences.

# Bar chart for caste distribution
df['Caste'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Voters by Caste')
plt.xlabel('Caste')
plt.ylabel('Count')
plt.show()

# %%
# Bar chart for average turnout by caste
turnout_by_caste.plot(kind='bar', color='skyblue')
plt.title('Average Turnout by Caste')
plt.xlabel('Caste')
plt.ylabel('Average Turnout (%)')
plt.show()

# %%
# Pie chart for total votes by state
votes_by_state.plot(kind='pie', autopct='%1.1f%%', colors=['lightcoral', 'lightskyblue', 'lightgreen'], startangle=140)
plt.title('Total Votes by State')
plt.ylabel('')  # Hides the y-label
plt.show()

# %%
# Stacked bar chart for votes by party and state
#Sort Party by Votes
df = df.sort_values(by='Votes', ascending=False)
print(df['Party'])
votes_by_party_state = df.pivot_table(index='State',columns = df['Party'][1:21] , values='Votes', aggfunc='sum', fill_value=0)

votes_by_party_state.plot(kind='bar', stacked=True)
plt.title('Votes by Party and State')
plt.xlabel('State')
plt.ylabel('Total Votes')
plt.legend(title='Party')
plt.show()
# Out:
# 2121      Indian National Congress
# 277          Bharatiya Janta Party
# 199          Bharatiya Janta Party
# 225          Bharatiya Janta Party
# 561          Bharatiya Janta Party
#                    ...
# 1242    Nationalist Congress Party
# 1218    Nationalist Congress Party
# 2467      Indian National Congress
# 1199           Janata Dal (United)
# 325          Bharatiya Janta Party
# Name: Party, Length: 2713, dtype: object

# %% [markdown]
# Margin of Victory:
# Probability: Probability of different margins of victory (e.g., close races vs. landslides).
#
# Statistics: Average margin of victory, standard deviation.
#
# Distribution: Distribution of victory margins across constituencies.

# %%
# Probability: Probability of different margins of victory (e.g., close races vs. landslides).
def classify_margin(margin_percent):
  if margin_percent <= 5:
    return "race close"
  elif margin_percent > 5 and margin_percent <= 10:
    return 'Moderate Race'
  else:
    return 'Landslide'

df['Margin Category'] = df['Margin %'].apply(classify_margin)

df
# df.drop('Margin Victory', axis=1, inplace=True)
# Out:
#                PC Name        Caste        State  \
# 2121            Dhubri          GEN        Assam
# 277         Malkajgiri          GEN    Telangana
# 199     Bangalore Rura          GEN    Karnataka
# 225   Darrang-Udalguri          GEN        Assam
# 561            Gauhati          GEN        Assam
# ...                ...          ...          ...
# 1242       Lakshadweep  Unspecified  Lakshadweep
# 1218       Lakshadweep           ST  Lakshadweep
# 2467       Lakshadweep           ST  Lakshadweep
# 1199       Lakshadweep           ST  Lakshadweep
# 325              Surat          GEN      Gujarat
#
#                                    Winning Candidate  \
# 2121                                 Rakibul Hussain
# 277                                  Eatala Rajender
# 199                                 Dr C N Manjunath
# 225                                     Dilip Saikia
# 561                                        Queen Oja
# ...

# %%
# Statistics: Average margin of victory, standard deviation.
df['Margin %'].describe()

#Average Margin of Victory
df['Margin %'].mean()

#Standard Deviation
df['Margin %'].std()
# Out:
# 0.11137756972549119

# %%
# Box plot for victory margins
plt.boxplot(df['Margin %'], vert=False, patch_artist=True, boxprops=dict(facecolor='skyblue'))
plt.title('Box Plot of Victory Margins')
plt.xlabel('Margin %')
plt.show()

# %%
# KDE plot for victory margins
df['Margin %'].plot(kind='density', color='skyblue')
plt.title('KDE Plot of Victory Margins')
plt.xlabel('Margin %')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# Correlation

# %%
corr_matrix = df[['Turnout','Margin','Margin %']].corr()

# %%
corr_matrix
# Out:
#            Turnout    Margin  Margin %
# Turnout   1.000000  0.170029  0.030465
# Margin    0.170029  1.000000  0.918455
# Margin %  0.030465  0.918455  1.000000

# %% [markdown]
# Visualize the Correlation Matrix

# %%
# Set plot style
sns.set(style="whitegrid")

# Create the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)

# Add plot title
plt.title('Correlation Matrix of Turnout and Margin Variables', fontsize=16)

# Show the plot
plt.show()

# %% [markdown]
# Turnout vs. Margin:
#
# 1. The correlation coefficient between Turnout and Margin is 0.17.
# 2. This indicates a weak positive correlation between voter turnout and the winning margin. As turnout increases, the margin tends to increase slightly.

# %% [markdown]
# Turnout vs. Margin %:
#
# 1. The correlation coefficient between Turnout and Margin % is 0.03.
# 2. This indicates a very weak positive correlation (almost negligible) between voter turnout and the margin percentage. There's hardly any relationship between the turnout and the margin percentage.

# %% [markdown]
# Margin vs. Margin %:
#
# 1. The correlation coefficient between Margin and Margin % is 0.92.
# 2. This indicates a very strong positive correlation between the margin and the margin percentage. As the absolute winning margin increases, the margin percentage also increases significantly. This is expected as a higher number of votes won will directly impact the percentage margin as well.

# %% [markdown]
# #Regression Analysis

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Define the feature and target variables
X_turnout = df[['Turnout']]
y_margin = df['Margin']
y_margin_pct = df['Margin %']

# %%
X_train_margin, X_test_margin, y_train_margin, y_test_margin = train_test_split(X_turnout, y_margin, test_size=0.2, random_state=42)

# Split the data into training and testing sets for Margin %
X_train_margin_pct, X_test_margin_pct, y_train_margin_pct, y_test_margin_pct = train_test_split(X_turnout, y_margin_pct, test_size=0.2, random_state=42)

# %%
# Create and train the linear regression model for Margin
model_margin = LinearRegression()
model_margin.fit(X_train_margin, y_train_margin)

# Create and train the linear regression model for Margin %
model_margin_pct = LinearRegression()
model_margin_pct.fit(X_train_margin_pct, y_train_margin_pct)
# Out:
# LinearRegression()

# %%
y_pred_margin = model_margin.predict(X_test_margin)
y_pred_margin_pct = model_margin_pct.predict(X_test_margin_pct)

# %%
y_pred_margin
# Out:
# array([165134.4183196 , 146038.34917781, 118918.72157308, 132558.77096008,
#        111537.04778718, 116190.71169568, 163690.17779628, 129188.87640564,
#         99180.76775425, 114425.52883384, 137854.31954561, 150050.12840928,
#        130633.11692897, 139459.0312382 , 171874.20742847, 123732.85665084,
#        156629.44634889, 153099.0806252 , 141705.62760783, 156148.03284111,
#        114104.58649532, 149247.77256299, 150692.01308632, 101427.36412388,
#        131275.00160601, 119560.60625012, 128867.93406712, 143470.81046967,
#        133842.54031415, 127744.63588231, 136570.55019154, 107846.21089423,
#        140421.85825376, 122128.14495826, 150692.01308632, 148445.41671669,
#         47990.46476071, 144433.63748522, 164813.47598109, 130151.70342119,
#        135126.30966822, 129670.28991342, 162566.87961146, 128546.99172861,
#        137854.31954561, 137693.84837636,  97576.05606167, 119721.07741937,
# ...

# %%
# Plot for Margin
plt.subplot(1, 2, 1)
plt.scatter(X_test_margin, y_test_margin, color='blue', label='Actual')
plt.plot(X_test_margin, y_pred_margin, color='red', linewidth=2, label='Predicted')
plt.title('Linear Regression: Turnout vs Margin')
plt.xlabel('Turnout')
plt.ylabel('Margin')
plt.legend()

# %%
# Plot for Margin %
plt.subplot(1, 2, 2)
plt.scatter(X_test_margin_pct, y_test_margin_pct, color='blue', label='Actual')
plt.plot(X_test_margin_pct, y_pred_margin_pct, color='red', linewidth=2, label='Predicted')
plt.title('Linear Regression: Turnout vs Margin %')
plt.xlabel('Turnout')
plt.ylabel('Margin %')
plt.legend()

# %%
df[df['Margin %']==0]
# Out:
#                   PC Name Caste            State         Winning Candidate  \
# 943          Machhlishahr    SC    Uttar Pradesh    Bholanath (B.P. Saroj)
# 1671    Mumbai North West   GEN      Maharashtra  Ravindra Dattaram Waikar
# 2461           Hoshiarpur    SC           Punjab         Santosh Chowdhary
# 2430  Tonk-Sawai Madhopur   GEN        Rajasthan               Namo Narain
# 429                Ladakh   GEN  Jammu & Kashmir         Thupstan Chhewang
#
#                          Party  Electors    Votes  Turnout  Margin  Margin %  \
# 943      Bharatiya Janta Party   1777073  1034925    0.589     181       0.0
# 1671                 Shiv Sena   1735088   954939    0.550      48       0.0
# 2461  Indian National Congress   1299234   843123    0.649     366       0.0
# 2430  Indian National Congress   1510047   802459    0.531     317       0.0
# 429      Bharatiya Janta Party    166763   118029    0.708      36       0.0
#
#       Year Margin Category
# ...

# %%
df[df['PC Name']=='Mumbai North West']
# Out:
#                 PC Name Caste        State             Winning Candidate  \
# 1671  Mumbai North West   GEN  Maharashtra      Ravindra Dattaram Waikar
# 1727  Mumbai North West   GEN  Maharashtra              Gajanan Kirtikar
# 1707  Mumbai North West   GEN  Maharashtra  Gajanan Chandrakant Kirtikar
# 2245  Mumbai North West   GEN  Maharashtra              Dutt Priya Sunil
# 2377  Mumbai North West   GEN  Maharashtra       Ad.Kamat Gurudas Vasant
#
#                          Party  Electors   Votes  Turnout  Margin  Margin %  \
# 1671                 Shiv Sena   1735088  954939    0.550      48     0.000
# 1727                 Shiv Sena   1908991  941497    0.503  260328     0.277
# 1707                 Shiv Sena   1775428  895517    0.504  183028     0.204
# 2245  Indian National Congress   1515745  747677    0.493   47358     0.063
# 2377  Indian National Congress   1604992  707303    0.441   38387     0.054
#
#       Year Margin Category
# 1671  2024      race close
# ...

# %%
party_wins = pd.DataFrame(df.groupby('PC Name')['Party'].value_counts(normalize=True)).reset_index()
party_wins = party_wins[party_wins['Party']=='Bharatiya Janta Party']

# %%
party_wins.columns = ['PC Name','Party','Win %']

# %%
#party_wins[party_wins['Win %']>=0.75]
party_wins[party_wins['Win %']==1]
# Out:
#                 PC Name                  Party  Win %
# 8             Ahmedabad  Bharatiya Janta Party    1.0
# 9        Ahmedabad East  Bharatiya Janta Party    1.0
# 10       Ahmedabad West  Bharatiya Janta Party    1.0
# 17                Akola  Bharatiya Janta Party    1.0
# 121            Bagalkot  Bharatiya Janta Party    1.0
# ...                 ...                    ...    ...
# 1392  Udupi Chikmagalur  Bharatiya Janta Party    1.0
# 1402     Uttara Kannada  Bharatiya Janta Party    1.0
# 1404           Vadodara  Bharatiya Janta Party    1.0
# 1418            Vidisha  Bharatiya Janta Party    1.0
# 1443           Yavatmal  Bharatiya Janta Party    1.0
#
# [114 rows x 3 columns]

# %%
df['Turnout'] = df['Turnout'].astype(float)
df['Margin %'] = df['Margin %'].astype(float)

# %%
df['Turnout_diff'] = df.groupby('Party')['Turnout'].diff().fillna(0)

# %%
dft = df[df['Party']=='Bharatiya Janta Party']

# %%
df['Margin_diff'] = df.groupby('Party')['Margin'].diff().fillna(0)

# %%
plt.figure(figsize=(8,6))
sns.lineplot(data=dft , x='Year' , y='Turnout')
plt.title('Year wise Turnout Trend for BJP')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.lineplot(data=dft , x='Year' , y='Margin %')
plt.title('Year wise Margin Trend for BJP')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.lineplot(data=df , x='Turnout_diff' , y='Margin_diff')
plt.title('Turnout vs MArgin for BJP')
plt.show()
